# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams.update({'figure.figsize':(15,6)})
plt.rcParams.update({'font.size':18})

# %%
df = pd.read_csv('dataset/customer_segmentation_traindata.csv')
df.head(3)
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  462809    Male           No   22        No  Healthcare              1.0
# 1  462643  Female          Yes   38       Yes    Engineer              NaN
# 2  466315  Female          Yes   67       Yes    Engineer              1.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
df.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    8068.000000  8068.000000      7239.000000  7733.000000
# mean   463479.214551    43.466906         2.641663     2.850123
# std      2595.381232    16.711696         3.406763     1.531413
# min    458982.000000    18.000000         0.000000     1.000000
# 25%    461240.750000    30.000000         0.000000     2.000000
# 50%    463472.500000    40.000000         1.000000     3.000000
# 75%    465744.250000    53.000000         4.000000     4.000000
# max    467974.000000    89.000000        14.000000     9.000000

# %% [markdown]
# ## EDA for every column

# %% [markdown]
# ### Gender

# %%
df['Gender'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### Ever_Married

# %%
df['Ever_Married'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### Age

# %%
sns.distplot(df['Age'],bins=40, kde=False)
plt.show()

# %% [markdown]
# ### Graduated

# %%
df['Graduated'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### Profession

# %%
df['Profession'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# ### Work_Experience

# %%
sns.distplot(df['Work_Experience'],bins=15, kde=False)
plt.show()

# %% [markdown]
# ### Spending_Score

# %%
df['Spending_Score'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### Family_Size

# %%
df['Family_Size'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### Var_1

# %%
df['Var_1'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### Segmentation

# %%
df['Segmentation'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ## Cross References

# %% [markdown]
# ### Gender by Segmentation

# %%
sns.countplot(x="Gender",hue="Segmentation",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Age by Segmentation

# %%
sns.histplot(x="Age",hue="Segmentation",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
## grid 2 x 2 of Age by different segments

# %% [markdown]
# ### Graduated by Segmentation

# %%
sns.countplot(x="Graduated",hue="Segmentation",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='Graduated', ylabel='count'>

# %% [markdown]
# ### Profession by Segmentation

# %%
sns.countplot(x="Profession",hue="Segmentation",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='count'>

# %% [markdown]
# ### Spending_Score by Segmentation

# %%
sns.countplot(x="Spending_Score",hue="Segmentation",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='count'>

# %% [markdown]
# ### Family_Size by Segmentation

# %%
sns.countplot(x="Family_Size",hue="Segmentation",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='Family_Size', ylabel='count'>
